# %% [markdown]
# # Sentiment analysis on movie reviews

# %% [markdown]
# In this notebook, we will explore basic NLP techniques to analyze movie reviews using the Large Movie Review Dataset, found in: https://ai.stanford.edu/~amaas/data/sentiment/

# %%
from collections import Counter

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords

import os

from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
import re

# %%
def load_imdb_data(path):
    data = []
    labels = []
    for label in ['pos', 'neg']:
        dir_path = f"{path}/{label}"
        for filename in os.listdir(dir_path):
            with open(f"{dir_path}/{filename}", 'r', encoding='utf-8') as file:
                data.append(file.read())
                labels.append(1 if label == 'pos' else 0)
    return pd.DataFrame({'review': data, 'sentiment': labels})

# %%
# Change this to the path where you unzipped the dataset
dataset_root = "./data/movie-reviews/aclImdb"

train_df = load_imdb_data(dataset_root + "/train")
test_df = load_imdb_data(dataset_root + "/test")

# %% [markdown]
# ## EDA
#
# Let's take a quick look at the data to understand the distribution of sentiments, the length of reviews, and some common words used in positive vs negative reviews.

# %%
sns.countplot(x='sentiment', data=train_df)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %% [markdown]
# As we can see, the dataset is balanced with an equal number of positive and negative reviews.
#
# Let's now look at the distribution of review lengths. First compute the length of each review, both in terms of characters and words, and then plot the distributions.

# %%
n_chars = train_df['review'].apply(len)
n_words = train_df['review'].apply(lambda s: len(s.split()))

review_length_df = pd.DataFrame({'chars': n_chars, 'words': n_words, 'sentiment': train_df['sentiment']})
review_length_df.describe().T
# Out:
#              count        mean          std   min    25%    50%     75%  \
# chars      25000.0  1325.06964  1003.133670  52.0  702.0  979.0  1614.0
# words      25000.0   233.78720   173.733032  10.0  127.0  174.0   284.0
# sentiment  25000.0     0.50000     0.500010   0.0    0.0    0.5     1.0
#
#                max
# chars      13704.0
# words       2470.0
# sentiment      1.0

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(review_length_df[review_length_df['sentiment'] == 1]['chars'], ax=axs[0], label='positive')
sns.histplot(review_length_df[review_length_df['sentiment'] == 0]['chars'], ax=axs[0], label='negative')
axs[0].set_title("Review length distribution (chars)")
axs[0].legend()

sns.histplot(review_length_df[review_length_df['sentiment'] == 1]['words'], ax=axs[1], label='positive')
sns.histplot(review_length_df[review_length_df['sentiment'] == 1]['words'], ax=axs[1], label='negative')
axs[1].set_title("Review length distribution (words)")
axs[1].legend()

# %% [markdown]
# As can be seen, the distribution of review lengths is quite similar for both positive and negative reviews, with most reviews being below 500 words. In terms of characters, most reviews have less than 3000 characters. This can be confirmed with boxplots, which show the "whiskers" of the distribution and any potential outliers.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

sns.boxplot(x='sentiment', y='chars', data=review_length_df, ax=axs[0])
axs[0].set_title("Review length (chars) by sentiment")

sns.boxplot(x='sentiment', y='words', data=review_length_df, ax=axs[1])
axs[1].set_title("Review length (words) by sentiment")
# Out:
# Text(0.5, 1.0, 'Review length (words) by sentiment')

# %%
def get_top_words(docs, n=20):
    all_words = ' '.join(docs).split()
    count_by_word = Counter(all_words)
    return [w for w, i in count_by_word.most_common(n)]

# %%
print("Top words in positive reviews:")
print(get_top_words(train_df[train_df['sentiment'] == 1]['review']))

print("\nTop words in negative reviews:")
print(get_top_words(train_df[train_df['sentiment'] == 0]['review']))
# Out:
# Top words in positive reviews:
# ['the', 'and', 'a', 'of', 'to', 'is', 'in', 'that', 'I', 'it', 'this', '/><br', 'as', 'with', 'was', 'for', 'The', 'but', 'his', 'on']
#
# Top words in negative reviews:
# ['the', 'a', 'and', 'of', 'to', 'is', 'in', 'I', 'that', 'this', 'it', '/><br', 'was', 'for', 'with', 'as', 'but', 'movie', 'The', 'on']

# %% [markdown]
# As we can see, the most common words in both positive and negative reviews are quite similar, with words like "the", "and", "a", "is" appearing frequently. Another issue is that this is case-insensitive, so "the" is treated as different that "The". To get a better idea of common words by sentiment, we can normalize the text by converting it to lowercase and removing any punctuation (and numbers, while we are at it).

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
print("Top words in positive reviews (normalized):")
print(get_top_words([normalize_text(t) for t in train_df[train_df['sentiment'] == 1]['review']]))

print("\nTop words in negative reviews (normalized):")
print(get_top_words([normalize_text(t) for t in train_df[train_df['sentiment'] == 0]['review']]))
# Out:
# Top words in positive reviews (normalized):
# ['the', 'and', 'a', 'of', 'to', 'is', 'in', 'it', 'i', 'this', 'that', 'br', 'as', 'with', 'for', 'was', 'but', 'film', 'movie', 'his']
#
# Top words in negative reviews (normalized):
# ['the', 'a', 'and', 'of', 'to', 'is', 'in', 'this', 'i', 'it', 'that', 'br', 'was', 'movie', 'for', 'but', 'with', 'as', 'film', 'on']

# %% [markdown]
# While most of the common words are still common stop words, at least we are now getting words like "movie" and "film". However, this still doesn't give us a good idea of which words are more associated with positive vs negative reviews.
#
# To deal with this, we will use the NLTK library to remove stop words.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Rafael\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords = stopwords.words('english')
print(stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# Some of these words are negations, such as "not", "no", "nor", which can be important for sentiment analysis. We will keep these in our list of stop words.

# %%
neg_words = [ 'no', 'nor', 'not', 'ain', 'aren', "aren't", 'don', "don't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

stopwords = [w for w in stopwords if w not in neg_words]

# %% [markdown]
# Let's redefine our `get_top_words` function to remove stop words before counting the most common words.

# %%
def get_top_words(docs, n=20, exclude=None):
    all_words = ' '.join(docs).split()
    if exclude is not None:
        all_words = [w for w in all_words if w not in exclude]
    count_by_word = Counter(all_words)
    return [w for w, i in count_by_word.most_common(n)]

# %%
# Ensure stopwords are processed in the same way as our documents (lowercased and punctuation removed)
norm_stopwords = set([normalize_text(w) for w in stopwords])

print("Top words in positive reviews (no stopwords):")
print(get_top_words([normalize_text(t) for t in train_df[train_df['sentiment'] == 1]['review']], exclude=norm_stopwords))

print("\nTop words in negative reviews (no stopwords):")
print(get_top_words([normalize_text(t) for t in train_df[train_df['sentiment'] == 0]['review']], exclude=norm_stopwords))
# Out:
# Top words in positive reviews (no stopwords):
# ['br', 'film', 'movie', 'not', 'one', 'like', 'good', 'story', 'great', 'time', 'see', 'also', 'really', 'would', 'even', 'first', 'much', 'no', 'people', 'films']
#
# Top words in negative reviews (no stopwords):
# ['br', 'movie', 'film', 'not', 'one', 'like', 'no', 'even', 'good', 'bad', 'would', 'really', 'time', 'see', 'dont', 'get', 'much', 'story', 'people', 'could']

# %% [markdown]
# We can now start to see some differences in the most common words between positive and negative reviews. Words like "good" and "great" are more common in positive reviews, while words like "bad" are now more common in negative reviews. That said, there is still a lot of overlap, since words like "movie", "film" and "story" are expected to appear in movie reviews regardless of the sentiment. We will deal with this later.

# %% [markdown]
# ## Vectorization
#
# We have now done some basic EDA to understand the data. The next step is to convert the text data into a format that can be used for machine learning models. One common approach is to use a bag-of-words representation, where we create a vector for each document that counts the occurrences of each word in the vocabulary. We can use the `CountVectorizer` from the `sklearn` library to do this.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(stop_words=stopwords, lowercase=True)
x_train = vectorizer.fit_transform(train_df['review'])
x_test = vectorizer.transform(test_df['review'])

# %% [markdown]
# Now that we vectorized our text data, let's compare the result with the original text.

# %%
print(train_df['review'][0])
print(x_train[0])
# Out:
# Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I'm here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 58 stored elements and shape (1, 74726)>
#   Coords	Values
#   (0, 9230)	4
#   (0, 30858)	5
#   (0, 10826)	1
#   (0, 13474)	1
#   (0, 53350)	1
#   (0, 66827)	1
#   (0, 51856)	1
#   (0, 57947)	2
#   (0, 38627)	1
#   (0, 65664)	4
#   (0, 646)	1
#   (0, 74040)	1
#   (0, 65666)	1
#   (0, 51797)	1
#   (0, 38022)	1
#   (0, 6702)	1
#   (0, 57502)	1
#   (0, 44180)	1
#   (0, 12911)	1
#   (0, 53748)	1
#   (0, 58140)	1
#   (0, 64599)	1
#   (0, 24591)	1
#   (0, 33770)	1
#   (0, 63685)	2
#   :	:
#   (0, 57968)	1
#   (0, 36809)	1
#   (0, 57614)	1
#   (0, 22187)	1
#   (0, 63684)	2
#   (0, 54872)	1
#   (0, 68045)	1
#   (0, 9744)	1
#   (0, 32680)	1
#   (0, 53885)	1
#   (0, 12652)	1
#   (0, 38815)	1
#   (0, 33811)	1
#   (0, 56943)	1
#   (0, 46864)	1
#   (0, 72437)	1
#   (0, 23093)	1
#   (0, 40771)	1
#   (0, 1917)	1
#   (0, 2150)	1
#   (0, 66431)	1
#   (0, 23754)	1
#   (0, 24297)	1
#   (0, 50078)	1
#   (0, 34592)	1

# %% [markdown]
# We can see that the vectorizer converts every review into a sparse vector of word counts, where the length of the vector is equal to the size of the vocabulary (the number of unique words in the training set after removing stop words). The `fit_transform` method learns the vocabulary from the training data and transforms it into vectors, while the `transform` method uses the same vocabulary to transform the test data.
#
# Each element in the vector corresponds to a word in the vocabulary, and the value of that element is the count of how many times that word appears in the review. Since most reviews will only contain a small subset of the total vocabulary, these vectors are typically very sparse (mostly zeros), which is why they are stored in a sparse format.
#
# Let's get the list of words that are present in the first review and their corresponding counts.

# %%
vec = x_train[0].toarray()[0].tolist()
word_count = [(idx, count) for idx, count in enumerate(vec) if count > 0]
print(word_count)
# Out:
# [(646, 1), (1917, 1), (2150, 1), (6702, 1), (9230, 4), (9744, 1), (10826, 1), (12652, 1), (12911, 1), (13474, 1), (22187, 1), (23093, 1), (23754, 1), (24297, 1), (24591, 1), (30858, 5), (32680, 1), (33770, 1), (33811, 1), (34592, 1), (36809, 1), (38022, 1), (38627, 1), (38815, 1), (40771, 1), (44180, 1), (46864, 1), (48620, 1), (49455, 1), (50078, 1), (50671, 1), (51797, 1), (51856, 1), (53350, 1), (53748, 1), (53885, 1), (54710, 1), (54872, 1), (55749, 1), (56943, 1), (57502, 1), (57614, 1), (57947, 2), (57968, 1), (58140, 1), (58506, 1), (60414, 1), (63684, 2), (63685, 2), (64599, 1), (65664, 4), (65666, 1), (66431, 1), (66827, 1), (68045, 1), (72437, 1), (72797, 1), (74040, 1)]

# %% [markdown]
# The previous cell gives us a list of tuples, where each tuple contains the index of a word in the vocabulary and the count of that word in the first review. To get the actual words, we can use the `get_feature_names_out` method of the vectorizer to get the list of words in the vocabulary and then map the indices to words.

# %%
for idx, count in word_count:
    print(f"{vectorizer.get_feature_names_out()[idx]}: {count}")
# Out:
# 35: 1
# adults: 1
# age: 1
# believe: 1
# bromwell: 4
# burn: 1
# cartoon: 1
# classic: 1
# closer: 1
# comedy: 1
# episode: 1
# expect: 1
# far: 1
# fetched: 1
# financially: 1
# high: 5
# immediately: 1
# insightful: 1
# inspector: 1
# isn: 1
# knew: 1
# lead: 1
# life: 1
# line: 1
# many: 1
# much: 1
# one: 1
# pathetic: 1
# pettiness: 1
# pity: 1
# pomp: 1
# profession: 1
# programs: 1
# ran: 1
# reality: 1
# recalled: 1
# remind: 1
# repeatedly: 1
# right: 1
# sack: 1
# satire: 1
# saw: 1
# school: 2
# schools: 1
# scramble: 1
# see: 1
# situation: 1
# student: 2
# students: 2
# survive: 1
# teachers: 4
# teaching: 1
# think: 1
# time: 1
# tried: 1
# welcome: 1
# whole: 1
# years: 1

# %% [markdown]
# One problem with CountVectorizer is that it gives equal weight to all words, regardless of how common they are across the entire corpus. This can lead to issues where very common words (like "movie", "film", "story") dominate the representation, even though they may not be very informative for distinguishing between positive and negative reviews. To address this, we can use the `TfidfVectorizer`, which stands for Term Frequency-Inverse Document Frequency. This vectorizer gives more weight to words that are more unique to a particular document and less weight to words that are common across all documents.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(stop_words=stopwords, lowercase=True)
x_train_tfidf = tfidf_vectorizer.fit_transform(train_df['review'])
x_test_tfidf = tfidf_vectorizer.transform(test_df['review'])

# %% [markdown]
# Now let's compare the TF-IDF representation with the original text and the CountVectorizer representation.

# %%
review_no_stopwords = ' '.join([w for w in train_df['review'][1].split() if w.lower() not in stopwords])
print("Original review:\n", train_df['review'][1])

print("\nOriginal review (no stopwords):\n", review_no_stopwords)

print("\nAs token IDs:\n", [vectorizer.vocabulary_.get(w.lower(), "-") for w in review_no_stopwords.split()])
# Out:
# Original review:
#  Homelessness (or Houselessness as George Carlin stated) has been an issue for years but never a plan to help those on the street that were once considered human who did everything from going to school, work, or vote for the matter. Most people think of the homeless as just a lost cause while worrying about things such as racism, the war on Iraq, pressuring kids to succeed, technology, the elections, inflation, or worrying if they'll be next to end up on the streets.<br /><br />But what if you were given a bet to live on the streets for a month without the luxuries you once had from a home, the entertainment sets, a bathroom, pictures on the wall, a computer, and everything you once treasure to see what it's like to be homeless? That is Goddard Bolt's lesson.<br /><br />Mel Brooks (who directs) who stars as Bolt plays a rich man who has everything in the world until deciding to make a bet with a sissy rival (Jeffery Tambor) to see if he can live in the streets for thirty days without the luxuries; if Bolt succeeds, he can do what he wants with a future project of making more buildings. The bet's on where Bolt is thrown on the street with a bracelet on his leg to monitor his every move where he can't step off the sidewalk. He's given the nickname Pepto by a vagrant after it's written on his forehead where Bolt meets other characters including a woman by the name of Molly (Lesley Ann Warren) an ex-dancer who got divorce before losing her home, and her pals Sailor (Howard Morris) and Fumes (Teddy Wilson) who are already used to the streets. They're survivors. Bolt isn't. He's not used to reaching mutual agreements like he once did when being rich where it's fight or flight, kill or be killed.<br /><br />While the love connection between Molly and Bolt wasn't necessary to plot, I found "Life Stinks" to be one of Mel Brooks' observant films where prior to being a comedy, it shows a tender side compared to his slapstick work such as Blazing Saddles, Young Frankenstein, or Spaceballs for the matter, to show what it's like having something valuable before losing it the next day or on the other hand making a stupid bet like all rich people do when they don't know what to do with their money. Maybe they should give it to the homeless instead of using it like Monopoly money.<br /><br />Or maybe this film will inspire you to help others.
#
# Original review (no stopwords):
#  Homelessness (or Houselessness George Carlin stated) issue years never plan help street considered human everything going school, work, vote matter. people think homeless lost cause worrying things racism, war Iraq, pressuring kids succeed, technology, elections, inflation, worrying next end streets.<br /><br />But given bet live streets month without luxuries home, entertainment sets, bathroom, pictures wall, computer, everything treasure see like homeless? Goddard Bolt's lesson.<br /><br />Mel Brooks (who directs) stars Bolt plays rich man everything world deciding make bet sissy rival (Jeffery Tambor) see live streets thirty days without luxuries; Bolt succeeds, wants future project making buildings. bet's Bolt thrown street bracelet leg monitor every move can't step sidewalk. given nickname Pepto vagrant written forehead Bolt meets characters including woman name Molly (Lesley Ann Warren) ex-dancer got divorce losing home, pals Sailor (Howard Morris) Fumes (Teddy Wilson) already used streets. survivors. Bolt isn't. not used reaching mutual agreements like rich fight flight, kill killed.<br /><br />While love connection Molly Bolt wasn't necessary plot, found "Life Stinks" one Mel Brooks' observant films prior comedy, shows tender side compared slapstick work Blazing Saddles, Young Frankenstein, Spaceballs matter, show like something valuable losing next day hand making stupid bet like rich people don't know money. Maybe give homeless instead using like Monopoly money.<br /><br />Or maybe film inspire help others.
#
# As token IDs:
#  [31363, '-', 31787, 27186, 10677, '-', 34620, 74040, 45366, 50152, 30508, 63487, 14285, 31973, 22739, 27928, '-', '-', 71654, '-', 49070, 66431, 31362, 39426, 11117, 73563, 66429, '-', 71993, '-', 51468, 36473, '-', '-', '-', '-', 73563, 45444, 21739, '-', '-', '-', 27584, 7045, 39000, 63496, 43644, 73246, 39846, '-', 22027, '-', '-', 49790, '-', '-', 22739, 67887, 58506, 38699, '-', 27874, '-', '-', '-', '-', 9262, '-', '-', 62813, 8218, 50260, 55635, 40533, 22739, 73533, 16909, 40363, 7045, 60382, 55915, '-', '-', 58506, 39000, 63496, 66463, 16686, 73246, '-', 8218, '-', 71991, 26417, 51876, 40383, '-', '-', 8218, 66617, 63487, 8708, 38163, 43544, 22729, 44073, '-', 63013, '-', 27584, 45511, 49097, 70542, 73722, 25468, 8218, 41920, 11611, 33088, 73355, 44786, 43452, '-', 3453, '-', '-', 28181, 19246, 39423, '-', 48082, 57062, '-', '-', 26294, '-', '-', 2808, 70403, '-', '-', 8218, '-', 45987, 70403, 53683, 44557, 2239, 38699, 55635, 24445, '-', 36504, '-', '-', '-', 39505, 14185, 43452, 8218, '-', 45104, '-', 25682, '-', '-', 46864, 41986, '-', 46432, 24549, 51638, '-', 59820, 65940, 60009, 13671, 60664, 73498, 7685, '-', 74215, '-', 61832, '-', 59792, 38699, 61555, 70627, 39423, 45444, 16673, 29614, 40383, 63748, 7045, 38699, 55635, 49070, '-', 36859, '-', 41461, 27581, 31362, 33841, 70422, 38699, 43575, '-', '-', '-', 41461, 24504, 33817, 30508, '-']

# %% [markdown]
# ## Training a model

# %% [markdown]
# Let's train a simple logistic regression model for this dataset.

# %% [markdown]
# To compare models fairly, we will keep the exact same logistic regression hyperparameters across all runs. Since reviews are loaded with all positives first and all negatives after, we will shuffle train/test once before running experiments so quick spot-checks are easier to interpret.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

RANDOM_STATE = 42

# Ensures dataset is shuffled
train_exp_df = train_df.sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)
test_exp_df = test_df.sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)

# %%
def run_experiment(vectorizer, preprocess_fn=None):
    train_text = train_exp_df['review']
    test_text = test_exp_df['review']

    if preprocess_fn is not None:
        train_text = train_text.apply(preprocess_fn)
        test_text = test_text.apply(preprocess_fn)

    x_train_vec = vectorizer.fit_transform(train_text)
    y_train = train_exp_df['sentiment']

    x_test_vec = vectorizer.transform(test_text)
    y_test = test_exp_df['sentiment']

    model = LogisticRegression(solver='liblinear', max_iter=1000, random_state=RANDOM_STATE)
    model.fit(x_train_vec, y_train)
    y_test_pred = model.predict(x_test_vec)
    y_train_pred = model.predict(x_train_vec)

    metrics = {
        'accuracy_train': accuracy_score(y_train, y_train_pred),
        'accuracy_test': accuracy_score(y_test, y_test_pred),
        'precision_train': precision_score(y_train, y_train_pred),
        'precision_test': precision_score(y_test, y_test_pred),
        'recall_train': recall_score(y_train, y_train_pred),
        'recall_test': recall_score(y_test, y_test_pred),
        'f1_train': f1_score(y_train, y_train_pred),
        'f1_test': f1_score(y_test, y_test_pred),
    }

    return model, vectorizer, metrics

# %%
experiments = [
    ('CountVectorizer', None, CountVectorizer(stop_words=stopwords, lowercase=True)),
    ('CountVectorizer-norm', normalize_text, CountVectorizer(stop_words=stopwords, lowercase=True)),
    ('TfidfVectorizer', None, TfidfVectorizer(stop_words=stopwords, lowercase=True)),
    ('TfidfVectorizer-norm', normalize_text, TfidfVectorizer(stop_words=stopwords, lowercase=True)),
]

results = []
model_runs = []
for exp_name, preprocess_fn, vectorizer in experiments:
    model, fitted_vectorizer, metrics = run_experiment(vectorizer, preprocess_fn=preprocess_fn)
    results.append({
        'vectorizer': exp_name,
        **metrics,
    })
    model_runs.append({
        'name': exp_name,
        'model': model,
        'fitted_vectorizer': fitted_vectorizer,
    })

results_df = pd.DataFrame(results).sort_values('accuracy_test', ascending=False)
results_df
# Out:
#              vectorizer  accuracy_train  accuracy_test  precision_train  \
# 2       TfidfVectorizer         0.93652        0.88304         0.929950
# 3  TfidfVectorizer-norm         0.93720        0.88224         0.931334
# 1  CountVectorizer-norm         0.99892        0.86528         0.999040
# 0       CountVectorizer         0.99832        0.86360         0.998480
#
#    precision_test  recall_train  recall_test  f1_train   f1_test
# 2        0.883347       0.94416      0.88264  0.937001  0.882993
# 3        0.882730       0.94400      0.88160  0.937624  0.882165
# 1        0.871220       0.99880      0.85728  0.998920  0.864194
# 0        0.869813       0.99816      0.85520  0.998320  0.862445

# %% [markdown]
# The table above compares all four configurations using the same logistic regression setup. You can use it to identify whether TF-IDF or CountVectorizer works better here, and whether applying `normalize_text` helps or hurts performance.

# %% [markdown]
# We can also look at the most important features for each model to see which words are driving the predictions. For logistic regression, we can look at the coefficients of the model to identify the most influential words for positive and negative sentiment.
#
# As a reminder, a logistic regression model computes scores between 0 and 1 using a linear equation, where each feature has a coefficient. The higher the coefficient, the more that feature contributes to predicting the positive class (sentiment=1), while a lower coefficient contributes to predicting the negative class (sentiment=0). Since each feature represents a word in the vocabulary, we can look at the coefficients to see which words are most strongly associated with positive and negative reviews.

# %%
def get_top_features(model, fitted_vectorizer, top_n=10):
    feature_names = fitted_vectorizer.get_feature_names_out()
    coefs = model.coef_[0]

    top_pos_idx = coefs.argsort()[::-1][:top_n]
    top_neg_idx = coefs.argsort()[:top_n]

    top_positive = [(feature_names[idx], coefs[idx]) for idx in top_pos_idx]
    top_negative = [(feature_names[idx], coefs[idx]) for idx in top_neg_idx]
    return top_positive, top_negative

def print_compact_feature_table(model_runs, sentiment='positive', top_n=10):
    table_data = {}

    for run in model_runs:
        top_positive, top_negative = get_top_features(run['model'], run['fitted_vectorizer'], top_n=top_n)
        selected = top_positive if sentiment == 'positive' else top_negative
        table_data[run['name']] = [f"{word} ({coef:.3f})" for word, coef in selected]

    compact_df = pd.DataFrame(table_data, index=[f"#{i}" for i in range(1, top_n + 1)])
    compact_df.index.name = 'rank'
    display(compact_df)

print('Top 10 positive words across experiments')
print_compact_feature_table(model_runs, sentiment='positive', top_n=10)

print('\nTop 10 negative words across experiments')
print_compact_feature_table(model_runs, sentiment='negative', top_n=10)
# Out:
# Top 10 positive words across experiments
#            CountVectorizer CountVectorizer-norm    TfidfVectorizer  \
# rank
# #1      refreshing (1.552)   refreshing (1.626)      great (7.241)
# #2     wonderfully (1.494)  wonderfully (1.455)  excellent (6.169)
# #3        funniest (1.350)     funniest (1.376)       best (5.193)
# #4          superb (1.330)    excellent (1.321)    perfect (4.840)
# #5          erotic (1.289)       superb (1.308)  wonderful (4.671)
# #6       excellent (1.282)       erotic (1.307)       well (4.447)
# #7         perfect (1.272)     flawless (1.278)    amazing (4.227)
# #8    surprisingly (1.252)      perfect (1.220)       love (4.059)
# #9          carrey (1.244)       hooked (1.216)   favorite (4.057)
# #10    appreciated (1.244)       subtle (1.215)        fun (3.936)
#
#      TfidfVectorizer-norm
# rank
# #1          great (7.296)
# #2      excellent (6.250)
# #3           best (5.278)
# #4        perfect (4.752)
# #5      wonderful (4.648)
# #6           well (4.209)
# #7       favorite (4.190)
# #8        amazing (4.172)
# #9           love (4.104)
# #10           fun (3.949)
# Top 10 negative words across experiments
#               CountVectorizer     CountVectorizer-norm    TfidfVectorizer  \
# rank
# #1    disappointment (-2.194)           waste (-2.206)     worst (-9.195)
# #2             worst (-2.187)           worst (-2.197)       bad (-7.509)
# #3             waste (-2.141)  disappointment (-2.133)     awful (-6.518)
# #4            poorly (-1.792)          poorly (-1.756)     waste (-6.396)
# #5             awful (-1.658)           awful (-1.660)    boring (-5.710)
# #6             lacks (-1.612)           lacks (-1.613)      poor (-5.322)
# #7     disappointing (-1.525)     forgettable (-1.476)   nothing (-4.839)
# #8              mess (-1.431)   disappointing (-1.453)  terrible (-4.783)
# #9           unfunny (-1.413)            mstk (-1.444)     worse (-4.662)
# #10           boring (-1.405)       laughable (-1.396)        no (-4.484)
#
#      TfidfVectorizer-norm
# rank
# #1         worst (-9.265)
# #2           bad (-7.643)
# #3         waste (-6.636)
# #4         awful (-6.410)
# #5        boring (-5.490)
# #6          poor (-5.385)
# #7       nothing (-4.895)
# #8      terrible (-4.828)
# #9         worse (-4.702)
# #10           no (-4.558)

# %% [markdown]
# ## Activity

# %% [markdown]
# #### Run 4 new experiments: 2 with CountVectorizer and 2 with TfidfVectorizer. For each vectorizer, apply stemming and lemmatization as the first step of your preprocessing function. Display the models metrics and top features as before.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('wordnet')
nltk.download('omw-1.4')

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def tokenize_for_preprocessing(text):
    text = normalize_text(text)
    return text.split()

def preprocess_with_stemming(text):
    tokens = tokenize_for_preprocessing(text)
    tokens = [stemmer.stem(token) for token in tokens]
    return ' '.join(tokens)

def preprocess_with_lemmatization(text):
    tokens = tokenize_for_preprocessing(text)
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(tokens)

base_stopwords_for_preprocessing = [normalize_text(w) for w in stopwords]
base_stopwords_for_preprocessing = [w for w in base_stopwords_for_preprocessing if w]

stemmed_stopwords = sorted({stemmer.stem(w) for w in base_stopwords_for_preprocessing})
lemmatized_stopwords = sorted({lemmatizer.lemmatize(w) for w in base_stopwords_for_preprocessing})
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Rafael\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Rafael\AppData\Roaming\nltk_data...

# %%
new_experiments = [
    ('CountVectorizer-stemming', preprocess_with_stemming, CountVectorizer(stop_words=stemmed_stopwords, lowercase=True)),
    ('CountVectorizer-lemmatization', preprocess_with_lemmatization, CountVectorizer(stop_words=lemmatized_stopwords, lowercase=True)),
    ('TfidfVectorizer-stemming', preprocess_with_stemming, TfidfVectorizer(stop_words=stemmed_stopwords, lowercase=True)),
    ('TfidfVectorizer-lemmatization', preprocess_with_lemmatization, TfidfVectorizer(stop_words=lemmatized_stopwords, lowercase=True)),
]

new_results = []
new_model_runs = []

for exp_name, preprocess_fn, vectorizer in new_experiments:
    model, fitted_vectorizer, metrics = run_experiment(vectorizer, preprocess_fn=preprocess_fn)
    new_results.append({
        'vectorizer': exp_name,
        **metrics,
    })
    new_model_runs.append({
        'name': exp_name,
        'preprocess_fn': preprocess_fn,
        'model': model,
        'fitted_vectorizer': fitted_vectorizer,
    })

new_results_df = pd.DataFrame(new_results).sort_values('accuracy_test', ascending=False)
new_results_df
# Out:
#                       vectorizer  accuracy_train  accuracy_test  \
# 3  TfidfVectorizer-lemmatization         0.93496        0.88164
# 2       TfidfVectorizer-stemming         0.92892        0.87700
# 1  CountVectorizer-lemmatization         0.99832        0.86028
# 0       CountVectorizer-stemming         0.99660        0.85380
#
#    precision_train  precision_test  recall_train  recall_test  f1_train  \
# 3         0.928245        0.880696       0.94280      0.88288  0.935466
# 2         0.921402        0.876789       0.93784      0.87728  0.929548
# 1         0.998400        0.867123       0.99824      0.85096  0.998320
# 0         0.996719        0.860579       0.99648      0.84440  0.996600
#
#     f1_test
# 3  0.881787
# 2  0.877034
# 1  0.858966
# 0  0.852413

# %%
print('Top 10 positive words across new experiments')
print_compact_feature_table(new_model_runs, sentiment='positive', top_n=10)

print('\nTop 10 negative words across new experiments')
print_compact_feature_table(new_model_runs, sentiment='negative', top_n=10)
# Out:
# Top 10 positive words across new experiments
#      CountVectorizer-stemming CountVectorizer-lemmatization  \
# rank
# #1            refresh (1.727)            refreshing (1.743)
# #2           flawless (1.656)              flawless (1.474)
# #3             driven (1.506)           wonderfully (1.435)
# #4              excel (1.443)              funniest (1.417)
# #5           squirrel (1.429)                superb (1.386)
# #6             superb (1.415)             excellent (1.338)
# #7               erot (1.343)                carrey (1.294)
# #8           funniest (1.322)                driven (1.260)
# #9          perfectli (1.257)                whoopi (1.248)
# #10             subtl (1.253)                subtle (1.238)
#
#      TfidfVectorizer-stemming TfidfVectorizer-lemmatization
# rank
# #1              great (7.114)                 great (7.202)
# #2              excel (6.569)             excellent (6.305)
# #3              enjoy (5.070)                  best (5.017)
# #4               love (5.065)               perfect (4.770)
# #5            perfect (4.901)             wonderful (4.614)
# #6               best (4.839)              favorite (4.605)
# #7            favorit (4.608)               amazing (4.167)
# #8             beauti (4.050)                 loved (3.999)
# #9                fun (3.952)                   fun (3.971)
# #10              amaz (3.854)                  love (3.885)
# Top 10 negative words across new experiments
#      CountVectorizer-stemming CountVectorizer-lemmatization  \
# rank
# #1             worst (-2.065)                worst (-2.178)
# #2            poorli (-1.881)       disappointment (-2.136)
# #3              mstk (-1.772)                waste (-2.067)
# #4                aw (-1.739)               poorly (-1.823)
# #5              wast (-1.640)                awful (-1.731)
# #6           unwatch (-1.558)        disappointing (-1.552)
# #7           forgett (-1.551)            laughable (-1.489)
# #8           unfunni (-1.551)                 mstk (-1.486)
# #9           alright (-1.516)                fails (-1.460)
# #10          baldwin (-1.511)              unfunny (-1.457)
#
#      TfidfVectorizer-stemming TfidfVectorizer-lemmatization
# rank
# #1             worst (-9.051)                worst (-9.297)
# #2              wast (-7.498)                  bad (-7.452)
# #3               bad (-7.146)                waste (-6.686)
# #4                aw (-6.688)                awful (-6.515)
# #5              bore (-6.013)               boring (-5.454)
# #6              poor (-5.283)                 poor (-5.343)
# #7           terribl (-4.805)              nothing (-4.857)
# #8        disappoint (-4.788)             terrible (-4.848)
# #9              wors (-4.728)                worse (-4.790)
# #10             noth (-4.707)                   no (-4.667)

# %% [markdown]
# #### Which vectorizer and preprocessing combination gives the best performance? Do you see any interesting differences in the top features across the different models?

# %%
top_feature_summary = []

for run in new_model_runs:
    top_positive, top_negative = get_top_features(run['model'], run['fitted_vectorizer'], top_n=10)
    top_feature_summary.append({
        'model': run['name'],
        'positive_top_features': ', '.join([word for word, coef in top_positive]),
        'negative_top_features': ', '.join([word for word, coef in top_negative]),
    })

top_feature_summary_df = pd.DataFrame(top_feature_summary)
top_feature_summary_df
# Out:
#                            model  \
# 0       CountVectorizer-stemming
# 1  CountVectorizer-lemmatization
# 2       TfidfVectorizer-stemming
# 3  TfidfVectorizer-lemmatization
#
#                                positive_top_features  \
# 0  refresh, flawless, driven, excel, squirrel, su...
# 1  refreshing, flawless, wonderfully, funniest, s...
# 2  great, excel, enjoy, love, perfect, best, favo...
# 3  great, excellent, best, perfect, wonderful, fa...
#
#                                negative_top_features
# 0  worst, poorli, mstk, aw, wast, unwatch, forget...
# 1  worst, disappointment, waste, poorly, awful, d...
# 2  worst, wast, bad, aw, bore, poor, terribl, dis...
# 3  worst, bad, waste, awful, boring, poor, nothin...

# %%
best_result = new_results_df.iloc[0]
best_model_name = best_result['vectorizer']
best_new_run = next(run for run in new_model_runs if run['name'] == best_model_name)

print(f"The best performing combination is {best_model_name}.")
print(f"Accuracy: {best_result['accuracy_test']:.4f}")
print(f"Precision: {best_result['precision_test']:.4f}")
print(f"Recall: {best_result['recall_test']:.4f}")
print(f"F1-score: {best_result['f1_test']:.4f}")
# Out:
# The best performing combination is TfidfVectorizer-lemmatization.
# Accuracy: 0.8816
# Precision: 0.8807
# Recall: 0.8829
# F1-score: 0.8818

# %%
positive_feature_sets = []
negative_feature_sets = []

for run in new_model_runs:
    top_positive, top_negative = get_top_features(run['model'], run['fitted_vectorizer'], top_n=10)
    positive_feature_sets.append(set([word for word, coef in top_positive]))
    negative_feature_sets.append(set([word for word, coef in top_negative]))

shared_positive_features = sorted(set.intersection(*positive_feature_sets))
shared_negative_features = sorted(set.intersection(*negative_feature_sets))

print("Interesting differences across models:")
print("Stemming usually creates shorter word roots, so some top features are less readable but group related forms of a word.")
print("Lemmatization keeps words closer to their dictionary form, so its top features are usually easier to interpret.")
print("CountVectorizer uses raw word counts, while TfidfVectorizer gives more importance to words that are more distinctive in a review.")
print()
print("Shared positive top features:", shared_positive_features)
print("Shared negative top features:", shared_negative_features)
# Out:
# Interesting differences across models:
# Stemming usually creates shorter word roots, so some top features are less readable but group related forms of a word.
# Lemmatization keeps words closer to their dictionary form, so its top features are usually easier to interpret.
# CountVectorizer uses raw word counts, while TfidfVectorizer gives more importance to words that are more distinctive in a review.
#
# Shared positive top features: []
# Shared negative top features: ['worst']

# %% [markdown]
# #### Write a review for the latest movie that you have seen. Then, use the best performing model to predict the sentiment of your review. Do you agree with the model's prediction? Why or why not?

# %%
my_review = """
Super Mario Galaxy is entertaining and funny, and it has good cameos. However, it does not really feel like Mario Galaxy. The game is defined by planet exploration and a cosmic atmosphere where traveling to other planets feels meaningful, with different cultures, logic, and environments. In the movie, it feels as if everything happens in the same world, only with different biomes. There is no real exploration and not much sense of space; the story could say that the characters are only traveling from country to country and almost nothing would change. The plot from the game and the movie feels almost nonexistent, and even the timeline is inconsistent. Peach and Toad leave their world at night and quickly arrive at an airport where a flight leaves in fifteen minutes, but during that tiny amount of time more than a day seems to pass in the Mushroom Kingdom: Mario and Luigi help the kingdom, get kidnapped, are taken to another planet, get arrested, escape, and still manage to find Peach before those fifteen minutes are over. Details like that make the separation plot feel unnecessary and confusing.
""".strip()

def predict_review_sentiment(review, run):
    review_text = pd.Series([review])

    if run['preprocess_fn'] is not None:
        review_text = review_text.apply(run['preprocess_fn'])

    x_review = run['fitted_vectorizer'].transform(review_text)
    predicted_class = run['model'].predict(x_review)[0]
    predicted_probability = run['model'].predict_proba(x_review)[0]

    return {
        'predicted_class': predicted_class,
        'sentiment': 'positive' if predicted_class == 1 else 'negative',
        'negative_probability': predicted_probability[0],
        'positive_probability': predicted_probability[1],
    }

review_prediction = predict_review_sentiment(my_review, best_new_run)

print("My review:")
print(my_review)
print()
print(f"Best model used: {best_new_run['name']}")
print(f"Predicted sentiment: {review_prediction['sentiment']}")
print(f"Negative probability: {review_prediction['negative_probability']:.4f}")
print(f"Positive probability: {review_prediction['positive_probability']:.4f}")
# Out:
# My review:
# Super Mario Galaxy is entertaining and funny, and it has good cameos. However, it does not really feel like Mario Galaxy. The game is defined by planet exploration and a cosmic atmosphere where traveling to other planets feels meaningful, with different cultures, logic, and environments. In the movie, it feels as if everything happens in the same world, only with different biomes. There is no real exploration and not much sense of space; the story could say that the characters are only traveling from country to country and almost nothing would change. The plot from the game and the movie feels almost nonexistent, and even the timeline is inconsistent. Peach and Toad leave their world at night and quickly arrive at an airport where a flight leaves in fifteen minutes, but during that tiny amount of time more than a day seems to pass in the Mushroom Kingdom: Mario and Luigi help the kingdom, get kidnapped, are taken to another planet, get arrested, escape, and still manage to find Peach before those fifteen minutes are over. Details like that make the separation plot feel unnecessary and confusing.
#
# Best model used: TfidfVectorizer-lemmatization
# Predicted sentiment: positive
# Negative probability: 0.4240
# Positive probability: 0.5760

# %%
if review_prediction['sentiment'] == 'negative':
    print("I agree with the model's prediction because the review is mostly critical. Even though it mentions that the movie is entertaining, funny, and has good cameos, most of the review focuses on missing exploration, weak cosmic atmosphere, a thin plot, and inconsistent timing.")
else:
    print("I do not fully agree with the model's prediction. The review includes some positive comments, but the main opinion is mostly critical because it argues that the movie does not capture the exploration, cosmic atmosphere, plot, or timing logic of Mario Galaxy.")
# Out:
# I do not fully agree with the model's prediction. The review includes some positive comments, but the main opinion is mostly critical because it argues that the movie does not capture the exploration, cosmic atmosphere, plot, or timing logic of Mario Galaxy.

# %% [markdown]
# #### Write your final remarks on this activity.

# %% [markdown]
# Although each vectorizer and preprocessing technique has its own functionality and specialty, in this case the best-performing combination was TfidfVectorizer with lemmatization. This model obtained an accuracy of 0.8816, precision of 0.8807, recall of 0.8829, and F1-score of 0.8818.
#
# For my own movie review, the best model predicted the sentiment as positive, with a negative probability of 0.4240 and a positive probability of 0.5760. However, I do not fully agree with this prediction because my review was actually more negative than positive. I intentionally started by praising the movie, saying that it was entertaining, funny, and had good cameos, but then I focused more on its problems, such as the lack of real space exploration, the weak connection to Super Mario Galaxy, and the inconsistencies in the plot and timeline.
#
# I think the model made this opposite prediction because these traditional models do not really understand the full context of a sentence or paragraph in the same way that models like GPT do. From what I understand, CountVectorizer and TfidfVectorizer work mainly by analyzing words and their frequency or importance, instead of truly understanding the meaning and intention behind the full review. Because of that, the model probably gave too much weight to positive words like “entertaining,” “funny,” and “good,” even though the general message of the review was a criticism.
#
# The differences in the top features also show this limitation. With stemming, some words were cut into less natural forms, such as “terribl,” “wast,” or “excel,” while lemmatization kept cleaner and easier-to-read words such as “terrible,” “waste,” and “excellent.” This makes lemmatization easier to interpret, but even with cleaner words, the model still did not fully understand that my review was mostly negative.
#
# Overall, the experiment helped me understand that these models can perform well statistically, but they can still fail when the sentiment depends on context, contrast, or criticism after praise. I am interested to see in the next activities how other models work and whether they can understand the context of a review better.
